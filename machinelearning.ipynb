# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy import signal
import pickle

# %%
def bp(y, fs=40/100, lowcut=.05, highcut=.1, order=3) :
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = signal.butter(order, [low, high], btype='band')
    return signal.lfilter(b, a, y)

def get_mov_rms(y, fs=40/100, window=150):
    return np.sqrt(signal.convolve(y**2, np.ones(int(fs*window))/int(fs*window), mode='same'))

def get_mov_mean(y, fs=40/100, window=150):
    return signal.convolve(y, np.ones(int(fs*window))/int(fs*window), mode='same')

# %% [markdown]
# #Read data

# %%
# !ls -lh /content/drive/MyDrive/MERMAIDAI/data/positive_300s_signals.pickle
# Out:
# -rw------- 1 root root 534M Oct 24 08:39 /content/drive/MyDrive/MERMAIDAI/data/positive_300s_signals.pickle

# %%
with open('/content/drive/MyDrive/MERMAIDAI/data/positive_1800s_signals.pickle', 'rb') as f:
  positive_1800s_signals = pickle.load(f)

print(positive_1800s_signals)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-5-341755ae3f9c> in <cell line: 1>()
#       1 with open('/content/drive/MyDrive/MERMAIDAI/data/positive_1800s_signals.pickle', 'rb') as f:
# ----> 2   positive_1800s_signals = pickle.load(f)
#       3
#       4 # Now you can work with the loaded data in the positive_300s_signals variable
#       5 print(positive_1800s_signals)
#
# EOFError: Ran out of input

# %%
with open('/content/drive/MyDrive/MERMAIDAI/data/negative_1800s_signals.pickle', 'rb') as f:
  negative_1800s_signals = pickle.load(f)

print(negative_1800s_signals)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-6-019b859f3aab> in <cell line: 1>()
#       1 with open('/content/drive/MyDrive/MERMAIDAI/data/negative_1800s_signals.pickle', 'rb') as f:
# ----> 2   negative_1800s_signals = pickle.load(f)
#       3
#       4 print(negative_1800s_signals)
#
# EOFError: Ran out of input
